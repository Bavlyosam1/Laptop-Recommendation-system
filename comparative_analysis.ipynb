# %% [markdown]
# ## Comparison Table

# %%
import pandas as pd

results = pd.DataFrame({

    "Metric": [
        "Training Loss",
        "Validation Loss",
        "BLEU Score",
        "Epochs"
    ],

    "ViT-GPT2": [
        2.70,
        2.71,
        0.034,
        3
    ],

    "EfficientNetB1-GRU": [
        2.30,
        3.82,
        "N/A",
        30
    ]
})

results
# Out:
#             Metric  ViT-GPT2 EfficientNetB1-GRU
# 0    Training Loss     2.700                2.3
# 1  Validation Loss     2.710               3.82
# 2       BLEU Score     0.034                N/A
# 3           Epochs     3.000                 30

# %%
import pandas as pd

comparison = pd.DataFrame({

    "Feature": [
        "Image Encoder",
        "Text Decoder",
        "Architecture Type",
        "Framework",
        "Training Type",
        "Epochs",
        "Learning Rate",
        "Dataset",
        "Strength"
    ],

    "ViT-GPT2": [
        "Vision Transformer (ViT)",
        "GPT2",
        "Transformer-Based",
        "PyTorch + HuggingFace",
        "Fine-Tuning",
        3,
        "2e-5",
        "Flickr30k",
        "Better contextual understanding"
    ],

    "EfficientNetB1-GRU": [
        "EfficientNetB1",
        "GRU",
        "CNN + RNN",
        "TensorFlow / Keras",
        "Transfer Learning",
        30,
        "1e-4",
        "Flickr30k",
        "Faster sequential learning"
    ]
})

comparison
# Out:
#              Feature                         ViT-GPT2  \
# 0      Image Encoder         Vision Transformer (ViT)
# 1       Text Decoder                             GPT2
# 2  Architecture Type                Transformer-Based
# 3          Framework            PyTorch + HuggingFace
# 4      Training Type                      Fine-Tuning
# 5             Epochs                                3
# 6      Learning Rate                             2e-5
# 7            Dataset                        Flickr30k
# 8           Strength  Better contextual understanding
#
#            EfficientNetB1-GRU
# 0              EfficientNetB1
# 1                         GRU
# 2                   CNN + RNN
# 3          TensorFlow / Keras
# 4           Transfer Learning
# 5                          30
# 6                        1e-4
# 7                   Flickr30k
# 8  Faster sequential learning

# %% [markdown]
# ## Architecture Comparison Graph

# %%
import matplotlib.pyplot as plt

models = ["ViT-GPT2", "EfficientNetB1-GRU"]

epochs = [3, 30]

plt.figure(figsize=(7,5))
plt.bar(models, epochs)

plt.ylabel("Epochs")
plt.title("Training Epochs Comparison")

plt.show()

# %% [markdown]
# ##  Learning Rate Comparison

# %%
learning_rates = [2e-5, 1e-4]

plt.figure(figsize=(7,5))
plt.bar(models, learning_rates)

plt.ylabel("Learning Rate")
plt.title("Learning Rate Comparison")

plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(r"D:\HNU books\project term 6\test\flickr\flickr30k_images\flickr30k_images\4414061.jpg")

plt.figure(figsize=(8,8))

plt.imshow(img)
plt.axis("off")

plt.figtext(
    0.5,
    0.02,
    """
ViT-GPT2:
A boy playing football in a field

EfficientNetB1-GRU:
A child playing soccer outdoors
""",
    ha="center",
    fontsize=11
)

plt.show()

# %% [markdown]
# # Final Reflection
#
# This comparative analysis demonstrated how different deep learning architectures affect image caption generation quality, contextual understanding, and computational efficiency.
#
# Transformer-based architectures provided richer semantic understanding, while CNN-RNN models achieved faster training and simpler computation.
